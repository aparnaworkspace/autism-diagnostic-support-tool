# %%
import joblib
from sklearn.preprocessing import StandardScaler

# 1. Identify ALL numeric columns (including age_group)
numeric_cols = X_train.select_dtypes(include=[np.number]).columns.tolist()
print("Numeric columns used for scaling:", numeric_cols)
print("Count:", len(numeric_cols))

# 2. Fit scaler on full numeric list
scaler = StandardScaler()
X_train[numeric_cols] = scaler.fit_transform(X_train[numeric_cols])
X_test[numeric_cols] = scaler.transform(X_test[numeric_cols])

# 3. Save the new scaler
joblib.dump(scaler, "../models/scaler.pkl")
print("Saved NEW scaler with", len(scaler.mean_), "features.")
# Out:
# Numeric columns used for scaling: ['a1_score', 'a2_score', 'a3_score', 'a4_score', 'a5_score', 'a6_score', 'a7_score', 'a8_score', 'a9_score', 'a10_score', 'age', 'gender', 'ethnicity', 'jundice', 'contry_of_res', 'used_app_before', 'age_desc', 'relation', 'age_group']
# Count: 19
# Saved NEW scaler with 19 features.

# %%
print(X_train.columns.tolist())
# Out:
# ['a1_score', 'a2_score', 'a3_score', 'a4_score', 'a5_score', 'a6_score', 'a7_score', 'a8_score', 'a9_score', 'a10_score', 'age', 'gender', 'ethnicity', 'jundice', 'contry_of_res', 'used_app_before', 'age_desc', 'relation', 'age_group']
